# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/tmp/Stu_Result1.csv')
data.head()
# Out:
#     1st   2nd   3rd   4th Students Name  Age  College Code  Gender  Roll no.  \
# 0  8.11  7.68  7.11  7.43         Komal   19           115  Female   17020.0
# 1  6.48  5.90   NaN  4.29           Ram   20           115    Male       NaN
# 2  8.41  8.24  7.52  8.25         Mohan   18           115    Male   17022.0
# 3  7.33  6.83  6.33  6.79         Sohan   19           115    Male   17023.0
# 4  7.89  7.34  7.22  7.32         Ratan   20           115    Male   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
print("Print missing values:")
data.isnull().sum()
# Out:
# Print missing values:
# 1st               2
# 2nd               4
# 3rd               3
# 4th               4
# Students Name     0
# Age               0
# College Code      0
# Gender            0
# Roll no.         12
# Subject Code      0
# dtype: int64

# %%
print("Fill 0 where the values are not given:")
data.fillna("0")
# Out:
# Fill 0 where the values are not given:
#      1st   2nd   3rd   4th Students Name  Age  College Code  Gender  \
# 0   8.11  7.68  7.11  7.43         Komal   19           115  Female
# 1   6.48   5.9     0  4.29           Ram   20           115    Male
# 2   8.41  8.24  7.52  8.25         Mohan   18           115    Male
# 3   7.33  6.83  6.33  6.79         Sohan   19           115    Male
# 4   7.89  7.34  7.22  7.32         Ratan   20           115    Male
# ..   ...   ...   ...   ...           ...  ...           ...     ...
# 94  5.85  5.66  4.59  5.86           Ram   21           116    Male
# 95  7.37  7.24  6.48  7.18         Mohan   22           116    Male
# 96  8.63  8.38  8.17  8.73         Sohan   24           116    Male
# 97  6.96  6.69  6.59  6.36         Ratan   22           116    Male
# 98  5.78  5.79  5.22  5.36         Kamal   20           116    Male
#
#      Roll no.  Subject Code
# 0     17020.0            16
# 1           0            16
# ...

# %%
summary_status = data.describe()
print("Summary Statistics:")
summary_status
# Out:
# Summary Statistics:
#              1st        2nd        3rd        4th        Age  College Code  \
# count  97.000000  95.000000  96.000000  95.000000  99.000000     99.000000
# mean    7.042887   6.928105   6.675937   7.059053  20.969697    138.303030
# std     0.957963   0.928669   0.835002   1.032362   1.775425     24.999369
# min     3.850000   3.900000   4.150000   4.290000  18.000000    115.000000
# 25%     6.480000   6.360000   6.250000   6.360000  20.000000    115.000000
# 50%     7.150000   6.790000   6.740000   7.180000  21.000000    116.000000
# 75%     7.850000   7.670000   7.260000   7.805000  22.000000    165.000000
# max     8.890000   8.720000   8.370000   9.250000  25.000000    165.000000
#
#            Roll no.  Subject Code
# count  8.700000e+01          99.0
# mean   7.688462e+04          16.0
# std    2.548613e+05           0.0
# min    5.760000e+02          16.0
# 25%    1.702650e+04          16.0
# 50%    1.704800e+04          16.0
# ...

# %%
#Distribution of ages
plt.figure(figsize=(8,6))
plt.hist(data['Age'],bins = 10,color='skyblue' , edgecolor= 'black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid('True')
plt.show()

# %%
#Gender Distribution
gender_counts = data['Gender'].value_counts()

plt.figure(figsize=(6,4))
gender_counts.plot(kind='bar', color=['yellow', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Gender Distribution Interpretation

total_count = gender_counts.sum()
male_percentage = (gender_counts['Male'] / total_count) * 100
female_percentage = (gender_counts['Female'] / total_count) * 100

print("Gender Distribution:")
print("Male count:",gender_counts['Male'])
print("Female count:",gender_counts['Female'])
print("Percentage of Males:",round(male_percentage, 2), "%")
print("Percentage of Females:",round(female_percentage, 2), "%")

# Age Distribution Interpretation
# Calculate mean and median age
mean_age = data['Age'].mean()
median_age = data['Age'].median()

print("\nAge Distribution:")
print("Mean Age:", round(mean_age, 2))
print("Median Age:", median_age)
# Out:
# Gender Distribution:
# Male count: 44
# Female count: 55
# Percentage of Males: 44.44 %
# Percentage of Females: 55.56 %
#
# Age Distribution:
# Mean Age: 20.97
# Median Age: 21.0
